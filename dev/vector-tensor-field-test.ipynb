# %%
using LowLevelFEM
# Out:
# [ Info: Precompiling LowLevelFEM [6171b9fb-adbf-4751-adb9-5faded75de07] (cache misses: include_dependency fsize change (2))
#
# SYSTEM: caught exception of type :MethodError while trying to print a failed Task notice; giving up

# %%
structured_box_mesh()
mat = Material("body")
prob = Problem([mat])
# Out:
# Problem("structured_box", :Solid, 3, 3, Material[Material("body", :Hooke, 200000.0, 0.3, 115384.61538461536, 76923.07692307692, 166666.66666666663, 7.85e-9, 45.0, 4.2e8, 1.2e-5, 1.0e-7, 0.1, 1.0)], 1.0, 1331, LowLevelFEM.Geometry("", "", 0, 0, nothing, nothing, nothing, nothing), :u, :f)

# %%
s = ScalarField(prob, "body", 0)
v = VectorField(prob, "body", [s, 1, 2])
t = TensorField(prob, "body", [s 1 2; 3 s 5; 6 7 8])
t.A[1]
# Out:
# 72×1 Matrix{Float64}:
#  0.0
#  3.0
#  6.0
#  1.0
#  0.0
#  7.0
#  2.0
#  5.0
#  8.0
#  0.0
#  3.0
#  6.0
#  1.0
#  ⋮
#  2.0
#  5.0
#  8.0
#  0.0
#  3.0
#  6.0
#  1.0
#  0.0
#  7.0
#  2.0
#  5.0
#  8.0
