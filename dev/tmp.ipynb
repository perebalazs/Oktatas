# %%
using LowLevelFEM

# %%
structured_rect_mesh()

mat = Material("body")
Pu = Problem([mat], type=:VectorField, dim=2)
# Out:
# Problem("structured_rect", :VectorField, 2, 2, Material[Material("body", :Hooke, 200000.0, 0.3, 115384.61538461536, 76923.07692307692, 166666.66666666663, 7.85e-9, 45.0, 4.2e8, 1.2e-5, 1.0e-7, 0.1, 1.0)], 1.0, 121, LowLevelFEM.Geometry("", "", 0, 0, nothing, nothing, nothing, nothing), :unknown, :rhs)

# %%
C = [0 0; 0 0; 0 0]
# Out:
# 3×2 Matrix{Int64}:
#  0  0
#  0  0
#  0  0

# %%
∫(SymGrad(Pu) ⋅ C ⋅ Pu)
# Out:
# sparse(Int64[], Int64[], Float64[], 242, 242)

# %%
SymGrad(Pu) ⋅ C
# Out:
# LowLevelFEM.MatrixChain(LowLevelFEM.OpApplied(Problem("structured_rect", :VectorField, 2, 2, Material[Material("body", :Hooke, 200000.0, 0.3, 115384.61538461536, 76923.07692307692, 166666.66666666663, 7.85e-9, 45.0, 4.2e8, 1.2e-5, 1.0e-7, 0.1, 1.0)], 1.0, 121, LowLevelFEM.Geometry("", "", 0, 0, nothing, nothing, nothing, nothing), :unknown, :rhs), LowLevelFEM.SymGradOp()), Any[[0 0; 0 0; 0 0]])

# %%
C ⋅ Pu
# Out:
# MethodError: no method matching iterate(::LowLevelFEM.OpApplied)
# The function `iterate` exists, but no method is defined for this combination of argument types.
#
# Closest candidates are:
#   iterate(::Compiler.ForwardToBackedgeIterator, ::Int64)
#    @ Base ~/.julia/juliaup/julia-1.12.6+0.x64.linux.gnu/share/julia/Compiler/src/typeinfer.jl:584
#   iterate(::Compiler.ForwardToBackedgeIterator)
#    @ Base ~/.julia/juliaup/julia-1.12.6+0.x64.linux.gnu/share/julia/Compiler/src/typeinfer.jl:584
#   iterate(::Base.MethodSpecializations)
#    @ Base runtime_internals.jl:1662
#   ...
#
#
# Stacktrace:
#  [1] dot(x::Matrix{Int64}, y::LowLevelFEM.OpApplied)
#    @ LinearAlgebra ~/.julia/juliaup/julia-1.12.6+0.x64.linux.gnu/share/julia/stdlib/v1.12/LinearAlgebra/src/generic.jl:952
#  [2] dot(x::Matrix{Int64}, P::Problem)
#    @ LowLevelFEM ~/Dokumentumok/GitHub/LowLevelFEM.jl/src/multifield.jl:2599
#  [3] top-level scope
#    @ In[7]:1
#  [4] eval(m::Module, e::Any)
# ...
