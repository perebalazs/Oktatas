# %%
using PyPlot;
x = collect(Float64, range(-10.,length=100,stop=10));
y = collect(Float64, range(-10.,length=100,stop=10));
z = 1 .- (abs.(x) + abs.(y))/1;
surf(x,y,z);
# Out:
# PyError ($(Expr(:escape, :(ccall(#= /home/perebal/.julia/packages/PyCall/1gn3u/src/pyfncall.jl:43 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'RuntimeError'>
# RuntimeError('Error in qhull Delaunay triangulation calculation: singular input data (exitcode=2); use python verbose option (-v) to see original qhull error.')
#   File "/usr/lib/python3/dist-packages/mpl_toolkits/mplot3d/axes3d.py", line 1775, in plot_trisurf
#     Triangulation.get_from_args_and_kwargs(*args, **kwargs)
#   File "/usr/lib/python3/dist-packages/matplotlib/tri/triangulation.py", line 161, in get_from_args_and_kwargs
#     triangulation = Triangulation(x, y, triangles, mask)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3/dist-packages/matplotlib/tri/triangulation.py", line 58, in __init__
#     self.triangles, self._neighbors = _qhull.delaunay(x, y)
#                                       ^^^^^^^^^^^^^^^^^^^^^
#
#
# Stacktrace:
# ...
