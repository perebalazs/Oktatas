# %%
using SymPy

# %%
function sx(s)
    x, y = symbols("x y")
    diff(diff(s, y), y)
end
function sy(s)
    x, y = symbols("x y")
    diff(diff(s, x), x)
end
function sxy(s)
    x, y = symbols("x y")
    -diff(diff(s, x), y)
end
function ΔΔ(f)
    x, y = symbols("x y")
    diff(diff(diff(diff(f, x), x), x), x) + 2 * diff(diff(diff(diff(f, x), x), y), y) + diff(diff(diff(diff(f, y), y), y), y)
end
function Δ(f)
    x, y = symbols("x y")
    diff(diff(f, x), x) + diff(diff(f, y), y)
end
# Out:
# Δ (generic function with 1 method)

# %%
function airy_ansatz(deg)
    x, y = symbols("x y")
    coeffs = Sym[]
    ϕ = 0

    k = 0
    for i in 0:deg
        for j in 0:(deg-i)
            C = symbols("C$k")
            push!(coeffs, C)
            ϕ += C * x^i * y^j
            k += 1
        end
    end

    return ϕ, coeffs
end
# Out:
# airy_ansatz (generic function with 1 method)

# %%
function coeff_equations(expr)
    x, y = symbols("x y")
    p = sympy.Poly(expr, x, y)
    return p.coeffs()
end
# Out:
# coeff_equations (generic function with 1 method)

# %%
function coeff_equations(expr)
    x, y = symbols("x y")
    return collect(values(expr.as_poly(x, y).as_dict()))
end
# Out:
# coeff_equations (generic function with 1 method)

# %%
ϕ, coeffs = airy_ansatz(6)
# Out:
# (C0 + C1*y + C10*x*y^3 + C11*x*y^4 + C12*x*y^5 + C13*x^2 + C14*x^2*y + C15*x^2*y^2 + C16*x^2*y^3 + C17*x^2*y^4 + C18*x^3 + C19*x^3*y + C2*y^2 + C20*x^3*y^2 + C21*x^3*y^3 + C22*x^4 + C23*x^4*y + C24*x^4*y^2 + C25*x^5 + C26*x^5*y + C27*x^6 + C3*y^3 + C4*y^4 + C5*y^5 + C6*y^6 + C7*x + C8*x*y + C9*x*y^2, Sym[C0, C1, C2, C3, C4, C5, C6, C7, C8, C9  …  C18, C19, C20, C21, C22, C23, C24, C25, C26, C27])

# %%
ΔΔϕ = ΔΔ(ϕ)
# Out:
#                                                     2           2              ↪
# 24⋅C₁₁⋅x + 120⋅C₁₂⋅x⋅y + 8⋅C₁₅ + 24⋅C₁₆⋅y + 24⋅C₁₇⋅x  + 48⋅C₁₇⋅y  + 24⋅C₂₀⋅x + ↪
#
# ↪                                           2           2                      ↪
# ↪  72⋅C₂₁⋅x⋅y + 24⋅C₂₂ + 24⋅C₂₃⋅y + 48⋅C₂₄⋅x  + 24⋅C₂₄⋅y  + 120⋅C₂₅⋅x + 120⋅C₂ ↪
#
# ↪                  2                              2
# ↪ ₆⋅x⋅y + 360⋅C₂₇⋅x  + 24⋅C₄ + 120⋅C₅⋅y + 360⋅C₆⋅y

# %%
ΔV = Δ(V)
# Out:
# UndefVarError: `V` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[9]:1
#  [2] eval(m::Module, e::Any)
#    @ Core ./boot.jl:489

# %%
ν = symbols("ν")
# Out:
# ν

# %%
eqs = coeff_equations(ΔΔϕ + (1 - ν) * ΔV)
# Out:
# 6-element Vector{Sym{PyCall.PyObject}}:
#      8⋅C₁₅ + 24⋅C₂₂ + 24⋅C₄
#   24⋅C₁₁ + 24⋅C₂₀ + 120⋅C₂₅
#   24⋅C₁₇ + 48⋅C₂₄ + 360⋅C₂₇
#    48⋅C₁₇ + 24⋅C₂₄ + 360⋅C₆
#    24⋅C₁₆ + 24⋅C₂₃ + 120⋅C₅
#  120⋅C₁₂ + 72⋅C₂₁ + 120⋅C₂₆

# %%
x, y = symbols("x y")
b, h = symbols("b h")
N, M, T, p, t, q = symbols("N M T p t q")
# Out:
# (N, M, T, p, t, q)

# %%
V = q * y
# Out:
# q⋅y

# %%
σx = sx(ϕ) + V
# Out:
#                       2             3          2          2             2  2   ↪
# 6⋅C₁₀⋅x⋅y + 12⋅C₁₁⋅x⋅y  + 20⋅C₁₂⋅x⋅y  + 2⋅C₁₅⋅x  + 6⋅C₁₆⋅x ⋅y + 12⋅C₁₇⋅x ⋅y  + ↪
#
# ↪                3          3            4                   2          3      ↪
# ↪  2⋅C₂ + 2⋅C₂₀⋅x  + 6⋅C₂₁⋅x ⋅y + 2⋅C₂₄⋅x  + 6⋅C₃⋅y + 12⋅C₄⋅y  + 20⋅C₅⋅y  + 30 ↪
#
# ↪      4
# ↪ ⋅C₆⋅y  + 2⋅C₉⋅x + q⋅y

# %%
σy = sy(ϕ) + V
# Out:
#                          2          3          4                               ↪
# 2⋅C₁₃ + 2⋅C₁₄⋅y + 2⋅C₁₅⋅y  + 2⋅C₁₆⋅y  + 2⋅C₁₇⋅y  + 6⋅C₁₈⋅x + 6⋅C₁₉⋅x⋅y + 6⋅C₂₀ ↪
#
# ↪     2            3           2           2             2  2           3      ↪
# ↪ ⋅x⋅y  + 6⋅C₂₁⋅x⋅y  + 12⋅C₂₂⋅x  + 12⋅C₂₃⋅x ⋅y + 12⋅C₂₄⋅x ⋅y  + 20⋅C₂₅⋅x  + 20 ↪
#
# ↪       3             4
# ↪ ⋅C₂₆⋅x ⋅y + 30⋅C₂₇⋅x  + q⋅y

# %%
τxy = sxy(ϕ)
# Out:
#          2          3          4                                  2            ↪
# - 3⋅C₁₀⋅y  - 4⋅C₁₁⋅y  - 5⋅C₁₂⋅y  - 2⋅C₁₄⋅x - 4⋅C₁₅⋅x⋅y - 6⋅C₁₆⋅x⋅y  - 8⋅C₁₇⋅x⋅ ↪
#
# ↪  3          2          2            2  2          3          3            4  ↪
# ↪ y  - 3⋅C₁₉⋅x  - 6⋅C₂₀⋅x ⋅y - 9⋅C₂₁⋅x ⋅y  - 4⋅C₂₃⋅x  - 8⋅C₂₄⋅x ⋅y - 5⋅C₂₆⋅x   ↪
#
# ↪
# ↪ - C₈ - 2⋅C₉⋅y

# %%
expN = integrate(σx, (y, -h / 2, h / 2))
expN = expN(x => b)
eqs = vcat(eqs, [expN])
# Out:
# 7-element Vector{Sym{PyCall.PyObject}}:
#                                                                                   8⋅C₁₅ + 24⋅C₂₂ + 24⋅C₄
#                                                                                24⋅C₁₁ + 24⋅C₂₀ + 120⋅C₂₅
#                                                                                24⋅C₁₇ + 48⋅C₂₄ + 360⋅C₂₇
#                                                                                 48⋅C₁₇ + 24⋅C₂₄ + 360⋅C₆
#                                                                                 24⋅C₁₆ + 24⋅C₂₃ + 120⋅C₅
#                                                                               120⋅C₁₂ + 72⋅C₂₁ + 120⋅C₂₆
#  3*C6*h^5/8 + h^3*(4*C11*b + 4*C17*b^2 + 4*C4)/4 + h*(2*C15*b^2 + 2*C2 + 2*C20*b^3 + 2*C24*b^4 + 2*C9*b)

# %%
expM = integrate(y * σx, (y, -h / 2, h / 2))
expM = expM(x => b)
eqs = vcat(eqs, [expM])
# Out:
# 8-element Vector{Sym{PyCall.PyObject}}:
#                                                                                   8⋅C₁₅ + 24⋅C₂₂ + 24⋅C₄
#                                                                                24⋅C₁₁ + 24⋅C₂₀ + 120⋅C₂₅
#                                                                                24⋅C₁₇ + 48⋅C₂₄ + 360⋅C₂₇
#                                                                                 48⋅C₁₇ + 24⋅C₂₄ + 360⋅C₆
#                                                                                 24⋅C₁₆ + 24⋅C₂₃ + 120⋅C₅
#                                                                               120⋅C₁₂ + 72⋅C₂₁ + 120⋅C₂₆
#  3*C6*h^5/8 + h^3*(4*C11*b + 4*C17*b^2 + 4*C4)/4 + h*(2*C15*b^2 + 2*C2 + 2*C20*b^3 + 2*C24*b^4 + 2*C9*b)
#                           h^5*(4*C12*b + 4*C5)/16 + h^3*(2*C10*b + 2*C16*b^2 + 2*C21*b^3 + 2*C3 + q/3)/4

# %%
expT = integrate(τxy, (y, -h / 2, h / 2))
expT = expT(x => b)
eqs = vcat(eqs, [expT])
# Out:
# 9-element Vector{Sym{PyCall.PyObject}}:
#                                                                                    8⋅C₁₅ + 24⋅C₂₂ + 24⋅C₄
#                                                                                 24⋅C₁₁ + 24⋅C₂₀ + 120⋅C₂₅
#                                                                                 24⋅C₁₇ + 48⋅C₂₄ + 360⋅C₂₇
#                                                                                  48⋅C₁₇ + 24⋅C₂₄ + 360⋅C₆
#                                                                                  24⋅C₁₆ + 24⋅C₂₃ + 120⋅C₅
#                                                                                120⋅C₁₂ + 72⋅C₂₁ + 120⋅C₂₆
#   3*C6*h^5/8 + h^3*(4*C11*b + 4*C17*b^2 + 4*C4)/4 + h*(2*C15*b^2 + 2*C2 + 2*C20*b^3 + 2*C24*b^4 + 2*C9*b)
#                            h^5*(4*C12*b + 4*C5)/16 + h^3*(2*C10*b + 2*C16*b^2 + 2*C21*b^3 + 2*C3 + q/3)/4
#  -C12*h^5/16 + h^3*(-C10 - 2*C16*b - 3*C21*b^2)/4 + h*(-2*C14*b - 3*C19*b^2 - 4*C23*b^3 - 5*C26*b^4 - C8)

# %%
s1 = σy(y => h / 2)
eqs = vcat(eqs, coeff_equations(s1))
# Out:
# 14-element Vector{Sym{PyCall.PyObject}}:
#                                                                                    8⋅C₁₅ + 24⋅C₂₂ + 24⋅C₄
#                                                                                 24⋅C₁₁ + 24⋅C₂₀ + 120⋅C₂₅
#                                                                                 24⋅C₁₇ + 48⋅C₂₄ + 360⋅C₂₇
#                                                                                  48⋅C₁₇ + 24⋅C₂₄ + 360⋅C₆
#                                                                                  24⋅C₁₆ + 24⋅C₂₃ + 120⋅C₅
#                                                                                120⋅C₁₂ + 72⋅C₂₁ + 120⋅C₂₆
#   3*C6*h^5/8 + h^3*(4*C11*b + 4*C17*b^2 + 4*C4)/4 + h*(2*C15*b^2 + 2*C2 + 2*C20*b^3 + 2*C24*b^4 + 2*C9*b)
#                            h^5*(4*C12*b + 4*C5)/16 + h^3*(2*C10*b + 2*C16*b^2 + 2*C21*b^3 + 2*C3 + q/3)/4
#  -C12*h^5/16 + h^3*(-C10 - 2*C16*b - 3*C21*b^2)/4 + h*(-2*C14*b - 3*C19*b^2 - 4*C23*b^3 - 5*C26*b^4 - C8)
#                                                 2*C13 + C14*h + C15*h^2/2 + C16*h^3/4 + C17*h^4/8 + h*q/2
#                                                               6*C18 + 3*C19*h + 3*C20*h^2/2 + 3*C21*h^3/4
#                                                                              12*C22 + 6*C23*h + 3*C24*h^2
#                                                                                         20⋅C₂₅ + 10⋅C₂₆⋅h
#                                                                                                    30⋅C₂₇

# %%
s1 = σy(y => -h / 2)
eqs = vcat(eqs, coeff_equations(s1))
# Out:
# 19-element Vector{Sym{PyCall.PyObject}}:
#                                                                                    8⋅C₁₅ + 24⋅C₂₂ + 24⋅C₄
#                                                                                 24⋅C₁₁ + 24⋅C₂₀ + 120⋅C₂₅
#                                                                                 24⋅C₁₇ + 48⋅C₂₄ + 360⋅C₂₇
#                                                                                  48⋅C₁₇ + 24⋅C₂₄ + 360⋅C₆
#                                                                                  24⋅C₁₆ + 24⋅C₂₃ + 120⋅C₅
#                                                                                120⋅C₁₂ + 72⋅C₂₁ + 120⋅C₂₆
#   3*C6*h^5/8 + h^3*(4*C11*b + 4*C17*b^2 + 4*C4)/4 + h*(2*C15*b^2 + 2*C2 + 2*C20*b^3 + 2*C24*b^4 + 2*C9*b)
#                            h^5*(4*C12*b + 4*C5)/16 + h^3*(2*C10*b + 2*C16*b^2 + 2*C21*b^3 + 2*C3 + q/3)/4
#  -C12*h^5/16 + h^3*(-C10 - 2*C16*b - 3*C21*b^2)/4 + h*(-2*C14*b - 3*C19*b^2 - 4*C23*b^3 - 5*C26*b^4 - C8)
#                                                 2*C13 + C14*h + C15*h^2/2 + C16*h^3/4 + C17*h^4/8 + h*q/2
#                                                               6*C18 + 3*C19*h + 3*C20*h^2/2 + 3*C21*h^3/4
#                                                                              12*C22 + 6*C23*h + 3*C24*h^2
#                                                                                         20⋅C₂₅ + 10⋅C₂₆⋅h
#                                                                                                    30⋅C₂₇
#                                                 2*C13 - C14*h + C15*h^2/2 - C16*h^3/4 + C17*h^4/8 - h*q/2
#                                                               6*C18 - 3*C19*h + 3*C20*h^2/2 - 3*C21*h^3/4
#                                                                              12*C22 - 6*C23*h + 3*C24*h^2
#                                                                                         20⋅C₂₅ - 10⋅C₂₆⋅h
#                                                                                                    30⋅C₂₇

# %%
s1 = τxy(y => h / 2)
eqs = vcat(eqs, coeff_equations(s1))
# Out:
# 24-element Vector{Sym{PyCall.PyObject}}:
#                                                                                    8⋅C₁₅ + 24⋅C₂₂ + 24⋅C₄
#                                                                                 24⋅C₁₁ + 24⋅C₂₀ + 120⋅C₂₅
#                                                                                 24⋅C₁₇ + 48⋅C₂₄ + 360⋅C₂₇
#                                                                                  48⋅C₁₇ + 24⋅C₂₄ + 360⋅C₆
#                                                                                  24⋅C₁₆ + 24⋅C₂₃ + 120⋅C₅
#                                                                                120⋅C₁₂ + 72⋅C₂₁ + 120⋅C₂₆
#   3*C6*h^5/8 + h^3*(4*C11*b + 4*C17*b^2 + 4*C4)/4 + h*(2*C15*b^2 + 2*C2 + 2*C20*b^3 + 2*C24*b^4 + 2*C9*b)
#                            h^5*(4*C12*b + 4*C5)/16 + h^3*(2*C10*b + 2*C16*b^2 + 2*C21*b^3 + 2*C3 + q/3)/4
#  -C12*h^5/16 + h^3*(-C10 - 2*C16*b - 3*C21*b^2)/4 + h*(-2*C14*b - 3*C19*b^2 - 4*C23*b^3 - 5*C26*b^4 - C8)
#                                                 2*C13 + C14*h + C15*h^2/2 + C16*h^3/4 + C17*h^4/8 + h*q/2
#                                                               6*C18 + 3*C19*h + 3*C20*h^2/2 + 3*C21*h^3/4
#                                                                              12*C22 + 6*C23*h + 3*C24*h^2
#                                                                                         20⋅C₂₅ + 10⋅C₂₆⋅h
#                                                                                                    30⋅C₂₇
#                                                 2*C13 - C14*h + C15*h^2/2 - C16*h^3/4 + C17*h^4/8 - h*q/2
#                                                               6*C18 - 3*C19*h + 3*C20*h^2/2 - 3*C21*h^3/4
#                                                                              12*C22 - 6*C23*h + 3*C24*h^2
#                                                                                         20⋅C₂₅ - 10⋅C₂₆⋅h
#                                                                                                    30⋅C₂₇
#                                                       -3*C10*h^2/4 - C11*h^3/2 - 5*C12*h^4/16 - C8 - C9*h
#                                                                  -2*C14 - 2*C15*h - 3*C16*h^2/2 - C17*h^3
#                                                                            -3*C19 - 3*C20*h - 9*C21*h^2/4
#                                                                                          -4⋅C₂₃ - 4⋅C₂₄⋅h
#                                                                                                    -5⋅C₂₆

# %%
s1 = τxy(y => -h / 2)
eqs = vcat(eqs, coeff_equations(s1))
# Out:
# 29-element Vector{Sym{PyCall.PyObject}}:
#                                                                                    8⋅C₁₅ + 24⋅C₂₂ + 24⋅C₄
#                                                                                 24⋅C₁₁ + 24⋅C₂₀ + 120⋅C₂₅
#                                                                                 24⋅C₁₇ + 48⋅C₂₄ + 360⋅C₂₇
#                                                                                  48⋅C₁₇ + 24⋅C₂₄ + 360⋅C₆
#                                                                                  24⋅C₁₆ + 24⋅C₂₃ + 120⋅C₅
#                                                                                120⋅C₁₂ + 72⋅C₂₁ + 120⋅C₂₆
#   3*C6*h^5/8 + h^3*(4*C11*b + 4*C17*b^2 + 4*C4)/4 + h*(2*C15*b^2 + 2*C2 + 2*C20*b^3 + 2*C24*b^4 + 2*C9*b)
#                            h^5*(4*C12*b + 4*C5)/16 + h^3*(2*C10*b + 2*C16*b^2 + 2*C21*b^3 + 2*C3 + q/3)/4
#  -C12*h^5/16 + h^3*(-C10 - 2*C16*b - 3*C21*b^2)/4 + h*(-2*C14*b - 3*C19*b^2 - 4*C23*b^3 - 5*C26*b^4 - C8)
#                                                 2*C13 + C14*h + C15*h^2/2 + C16*h^3/4 + C17*h^4/8 + h*q/2
#                                                               6*C18 + 3*C19*h + 3*C20*h^2/2 + 3*C21*h^3/4
#                                                                              12*C22 + 6*C23*h + 3*C24*h^2
#                                                                                         20⋅C₂₅ + 10⋅C₂₆⋅h
#                                                                                                         ⋮
#                                                                                         20⋅C₂₅ - 10⋅C₂₆⋅h
#                                                                                                    30⋅C₂₇
#                                                       -3*C10*h^2/4 - C11*h^3/2 - 5*C12*h^4/16 - C8 - C9*h
#                                                                  -2*C14 - 2*C15*h - 3*C16*h^2/2 - C17*h^3
#                                                                            -3*C19 - 3*C20*h - 9*C21*h^2/4
#                                                                                          -4⋅C₂₃ - 4⋅C₂₄⋅h
#                                                                                                    -5⋅C₂₆
#                                                       -3*C10*h^2/4 + C11*h^3/2 - 5*C12*h^4/16 - C8 + C9*h
#                                                                  -2*C14 + 2*C15*h - 3*C16*h^2/2 + C17*h^3
#                                                                            -3*C19 + 3*C20*h - 9*C21*h^2/4
#                                                                                          -4⋅C₂₃ + 4⋅C₂₄⋅h
#                                                                                                    -5⋅C₂₆

# %%
sol = solve(eqs, coeffs)
# Out:
# Dict{Sym{PyCall.PyObject}, Sym{PyCall.PyObject}} with 25 entries:
#   C6  => 0
#   C3  => (15*b^2*q - h^2*q)/(15*h^2)
#   C17 => 0
#   C8  => 3*b*q/2
#   C21 => 0
#   C24 => 0
#   C11 => 0
#   C9  => 0
#   C26 => 0
#   C19 => 0
#   C22 => 0
#   C25 => 0
#   C13 => 0
#   C5  => -q/(5*h^2)
#   C20 => 0
#   C23 => 0
#   C16 => q/h^2
#   C12 => 0
#   C2  => 0
#   C27 => 0
#   C18 => 0
#   C15 => 0
#   C4  => 0
#   C10 => -2*b*q/h^2
#   C14 => -3*q/4

# %%
ϕ_sol = subs(ϕ, sol)
# Out:
#                                         3        2        2  3      5    3 ⎛   ↪
#                    3⋅b⋅q⋅x⋅y   2⋅b⋅q⋅x⋅y    3⋅q⋅x ⋅y   q⋅x ⋅y    q⋅y    y ⋅⎝15 ↪
# C₀ + C₁⋅y + C₇⋅x + ───────── - ────────── - ──────── + ─────── - ──── + ────── ↪
#                        2            2          4          2         2          ↪
#                                    h                     h       5⋅h           ↪
#
# ↪   2      2  ⎞
# ↪ ⋅b ⋅q - h ⋅q⎠
# ↪ ─────────────
# ↪      2
# ↪  15⋅h

# %%
σx = sx(ϕ_sol) + V
factor(σx)
# Out:
#     ⎛    2               2       2       2⎞
# q⋅y⋅⎝30⋅b  - 60⋅b⋅x + 3⋅h  + 30⋅x  - 20⋅y ⎠
# ───────────────────────────────────────────
#                       2
#                    5⋅h

# %%
σy = sy(ϕ_sol) + V
# Out:
#              3
#   q⋅y   2⋅q⋅y
# - ─── + ──────
#    2       2
#           h

# %%
τxy = sxy(ϕ_sol)
simplify(τxy)
# Out:
#     ⎛     2    2                 2⎞
# 3⋅q⋅⎝4⋅b⋅y  + h ⋅(-b + x) - 4⋅x⋅y ⎠
# ───────────────────────────────────
#                   2
#                2⋅h
