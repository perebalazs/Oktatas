# %%
using SymPy

# %%
function sx(s)
    x, y = symbols("x y")
    diff(diff(s, y), y)
end
function sy(s)
    x, y = symbols("x y")
    diff(diff(s, x), x)
end
function sxy(s)
    x, y = symbols("x y")
    -diff(diff(s, x), y)
end
function ΔΔ(f)
    x, y = symbols("x y")
    diff(diff(diff(diff(f, x), x), x), x) + 2 * diff(diff(diff(diff(f, x), x), y), y) + diff(diff(diff(diff(f, y), y), y), y)
end
# Out:
# ΔΔ (generic function with 1 method)

# %%
function airy_ansatz(deg)
    x, y = symbols("x y")
    coeffs = Sym[]
    ϕ = 0

    k = 0
    for i in 0:deg
        for j in 0:(deg-i)
            C = symbols("C$k")
            push!(coeffs, C)
            ϕ += C * x^i * y^j
            k += 1
        end
    end

    return ϕ, coeffs
end
# Out:
# airy_ansatz (generic function with 1 method)

# %%
function coeff_equations(expr)
    x, y = symbols("x y")
    p = sympy.Poly(expr, x, y)
    return p.coeffs()
end
# Out:
# coeff_equations (generic function with 1 method)

# %%
function coeff_equations(expr)
    x, y = symbols("x y")
    return collect(values(expr.as_poly(x, y).as_dict()))
end
# Out:
# coeff_equations (generic function with 1 method)

# %%
ϕ, coeffs = airy_ansatz(5)
# Out:
# (C0 + C1*y + C10*x*y^4 + C11*x^2 + C12*x^2*y + C13*x^2*y^2 + C14*x^2*y^3 + C15*x^3 + C16*x^3*y + C17*x^3*y^2 + C18*x^4 + C19*x^4*y + C2*y^2 + C20*x^5 + C3*y^3 + C4*y^4 + C5*y^5 + C6*x + C7*x*y + C8*x*y^2 + C9*x*y^3, Sym[C0, C1, C2, C3, C4, C5, C6, C7, C8, C9  …  C11, C12, C13, C14, C15, C16, C17, C18, C19, C20])

# %%
ΔΔϕ = ΔΔ(ϕ)
# Out:
# 24⋅C₁₀⋅x + 8⋅C₁₃ + 24⋅C₁₄⋅y + 24⋅C₁₇⋅x + 24⋅C₁₈ + 24⋅C₁₉⋅y + 120⋅C₂₀⋅x + 24⋅C₄ ↪
#
# ↪  + 120⋅C₅⋅y

# %%
eqs = coeff_equations(ΔΔϕ)
# Out:
# 3-element Vector{Sym{PyCall.PyObject}}:
#     8⋅C₁₃ + 24⋅C₁₈ + 24⋅C₄
#  24⋅C₁₀ + 24⋅C₁₇ + 120⋅C₂₀
#   24⋅C₁₄ + 24⋅C₁₉ + 120⋅C₅

# %%
x, y = symbols("x y")
b, h = symbols("b h")
N, M, T, p = symbols("N M T p")
# Out:
# (N, M, T, p)

# %%
σx = sx(ϕ)
# Out:
#           2          2          2            3                          2      ↪
# 12⋅C₁₀⋅x⋅y  + 2⋅C₁₃⋅x  + 6⋅C₁₄⋅x ⋅y + 2⋅C₁₇⋅x  + 2⋅C₂ + 6⋅C₃⋅y + 12⋅C₄⋅y  + 20 ↪
#
# ↪      3
# ↪ ⋅C₅⋅y  + 2⋅C₈⋅x + 6⋅C₉⋅x⋅y

# %%
σy = sy(ϕ)
# Out:
#                          2          3                                  2       ↪
# 2⋅C₁₁ + 2⋅C₁₂⋅y + 2⋅C₁₃⋅y  + 2⋅C₁₄⋅y  + 6⋅C₁₅⋅x + 6⋅C₁₆⋅x⋅y + 6⋅C₁₇⋅x⋅y  + 12⋅ ↪
#
# ↪      2           2             3
# ↪ C₁₈⋅x  + 12⋅C₁₉⋅x ⋅y + 20⋅C₂₀⋅x

# %%
τxy = sxy(ϕ)
# Out:
#          3                                  2          2          2            ↪
# - 4⋅C₁₀⋅y  - 2⋅C₁₂⋅x - 4⋅C₁₃⋅x⋅y - 6⋅C₁₄⋅x⋅y  - 3⋅C₁₆⋅x  - 6⋅C₁₇⋅x ⋅y - 4⋅C₁₉⋅ ↪
#
# ↪  3                       2
# ↪ x  - C₇ - 2⋅C₈⋅y - 3⋅C₉⋅y

# %%
expN = integrate(σx, (y, -h / 2, h / 2))
expN = expN(x => b)
eqs = vcat(eqs, [expN])
# Out:
# 4-element Vector{Sym{PyCall.PyObject}}:
#                                              8⋅C₁₃ + 24⋅C₁₈ + 24⋅C₄
#                                           24⋅C₁₀ + 24⋅C₁₇ + 120⋅C₂₀
#                                            24⋅C₁₄ + 24⋅C₁₉ + 120⋅C₅
#  h^3*(4*C10*b + 4*C4)/4 + h*(2*C13*b^2 + 2*C17*b^3 + 2*C2 + 2*C8*b)

# %%
expM = integrate(y * σx, (y, -h / 2, h / 2))
expM = expM(x => b)
eqs = vcat(eqs, [expM])
# Out:
# 5-element Vector{Sym{PyCall.PyObject}}:
#                                              8⋅C₁₃ + 24⋅C₁₈ + 24⋅C₄
#                                           24⋅C₁₀ + 24⋅C₁₇ + 120⋅C₂₀
#                                            24⋅C₁₄ + 24⋅C₁₉ + 120⋅C₅
#  h^3*(4*C10*b + 4*C4)/4 + h*(2*C13*b^2 + 2*C17*b^3 + 2*C2 + 2*C8*b)
#                        C5*h^5/4 + h^3*(2*C14*b^2 + 2*C3 + 2*C9*b)/4

# %%
expT = integrate(τxy, (y, -h / 2, h / 2))
expT = expT(x => b)
eqs = vcat(eqs, [expT])
# Out:
# 6-element Vector{Sym{PyCall.PyObject}}:
#                                              8⋅C₁₃ + 24⋅C₁₈ + 24⋅C₄
#                                           24⋅C₁₀ + 24⋅C₁₇ + 120⋅C₂₀
#                                            24⋅C₁₄ + 24⋅C₁₉ + 120⋅C₅
#  h^3*(4*C10*b + 4*C4)/4 + h*(2*C13*b^2 + 2*C17*b^3 + 2*C2 + 2*C8*b)
#                        C5*h^5/4 + h^3*(2*C14*b^2 + 2*C3 + 2*C9*b)/4
#   h^3*(-2*C14*b - C9)/4 + h*(-2*C12*b - 3*C16*b^2 - 4*C19*b^3 - C7)

# %%
s1 = σy(y => h / 2) - p
eqs = vcat(eqs, coeff_equations(s1))
# Out:
# 10-element Vector{Sym{PyCall.PyObject}}:
#                                              8⋅C₁₃ + 24⋅C₁₈ + 24⋅C₄
#                                           24⋅C₁₀ + 24⋅C₁₇ + 120⋅C₂₀
#                                            24⋅C₁₄ + 24⋅C₁₉ + 120⋅C₅
#  h^3*(4*C10*b + 4*C4)/4 + h*(2*C13*b^2 + 2*C17*b^3 + 2*C2 + 2*C8*b)
#                        C5*h^5/4 + h^3*(2*C14*b^2 + 2*C3 + 2*C9*b)/4
#   h^3*(-2*C14*b - C9)/4 + h*(-2*C12*b - 3*C16*b^2 - 4*C19*b^3 - C7)
#                           2*C11 + C12*h + C13*h^2/2 + C14*h^3/4 - p
#                                       6*C15 + 3*C16*h + 3*C17*h^2/2
#                                                    12⋅C₁₈ + 6⋅C₁₉⋅h
#                                                              20⋅C₂₀

# %%
s1 = σy(y => -h / 2)
eqs = vcat(eqs, coeff_equations(s1))
# Out:
# 14-element Vector{Sym{PyCall.PyObject}}:
#                                              8⋅C₁₃ + 24⋅C₁₈ + 24⋅C₄
#                                           24⋅C₁₀ + 24⋅C₁₇ + 120⋅C₂₀
#                                            24⋅C₁₄ + 24⋅C₁₉ + 120⋅C₅
#  h^3*(4*C10*b + 4*C4)/4 + h*(2*C13*b^2 + 2*C17*b^3 + 2*C2 + 2*C8*b)
#                        C5*h^5/4 + h^3*(2*C14*b^2 + 2*C3 + 2*C9*b)/4
#   h^3*(-2*C14*b - C9)/4 + h*(-2*C12*b - 3*C16*b^2 - 4*C19*b^3 - C7)
#                           2*C11 + C12*h + C13*h^2/2 + C14*h^3/4 - p
#                                       6*C15 + 3*C16*h + 3*C17*h^2/2
#                                                    12⋅C₁₈ + 6⋅C₁₉⋅h
#                                                              20⋅C₂₀
#                               2*C11 - C12*h + C13*h^2/2 - C14*h^3/4
#                                       6*C15 - 3*C16*h + 3*C17*h^2/2
#                                                    12⋅C₁₈ - 6⋅C₁₉⋅h
#                                                              20⋅C₂₀

# %%
s1 = τxy(y => h / 2)
eqs = vcat(eqs, coeff_equations(s1))
# Out:
# 18-element Vector{Sym{PyCall.PyObject}}:
#                                              8⋅C₁₃ + 24⋅C₁₈ + 24⋅C₄
#                                           24⋅C₁₀ + 24⋅C₁₇ + 120⋅C₂₀
#                                            24⋅C₁₄ + 24⋅C₁₉ + 120⋅C₅
#  h^3*(4*C10*b + 4*C4)/4 + h*(2*C13*b^2 + 2*C17*b^3 + 2*C2 + 2*C8*b)
#                        C5*h^5/4 + h^3*(2*C14*b^2 + 2*C3 + 2*C9*b)/4
#   h^3*(-2*C14*b - C9)/4 + h*(-2*C12*b - 3*C16*b^2 - 4*C19*b^3 - C7)
#                           2*C11 + C12*h + C13*h^2/2 + C14*h^3/4 - p
#                                       6*C15 + 3*C16*h + 3*C17*h^2/2
#                                                    12⋅C₁₈ + 6⋅C₁₉⋅h
#                                                              20⋅C₂₀
#                               2*C11 - C12*h + C13*h^2/2 - C14*h^3/4
#                                       6*C15 - 3*C16*h + 3*C17*h^2/2
#                                                    12⋅C₁₈ - 6⋅C₁₉⋅h
#                                                              20⋅C₂₀
#                                 -C10*h^3/2 - C7 - C8*h - 3*C9*h^2/4
#                                      -2*C12 - 2*C13*h - 3*C14*h^2/2
#                                                    -3⋅C₁₆ - 3⋅C₁₇⋅h
#                                                              -4⋅C₁₉

# %%
s1 = τxy(y => -h / 2)
eqs = vcat(eqs, coeff_equations(s1))
# Out:
# 22-element Vector{Sym{PyCall.PyObject}}:
#                                              8⋅C₁₃ + 24⋅C₁₈ + 24⋅C₄
#                                           24⋅C₁₀ + 24⋅C₁₇ + 120⋅C₂₀
#                                            24⋅C₁₄ + 24⋅C₁₉ + 120⋅C₅
#  h^3*(4*C10*b + 4*C4)/4 + h*(2*C13*b^2 + 2*C17*b^3 + 2*C2 + 2*C8*b)
#                        C5*h^5/4 + h^3*(2*C14*b^2 + 2*C3 + 2*C9*b)/4
#   h^3*(-2*C14*b - C9)/4 + h*(-2*C12*b - 3*C16*b^2 - 4*C19*b^3 - C7)
#                           2*C11 + C12*h + C13*h^2/2 + C14*h^3/4 - p
#                                       6*C15 + 3*C16*h + 3*C17*h^2/2
#                                                    12⋅C₁₈ + 6⋅C₁₉⋅h
#                                                              20⋅C₂₀
#                               2*C11 - C12*h + C13*h^2/2 - C14*h^3/4
#                                       6*C15 - 3*C16*h + 3*C17*h^2/2
#                                                    12⋅C₁₈ - 6⋅C₁₉⋅h
#                                                              20⋅C₂₀
#                                 -C10*h^3/2 - C7 - C8*h - 3*C9*h^2/4
#                                      -2*C12 - 2*C13*h - 3*C14*h^2/2
#                                                    -3⋅C₁₆ - 3⋅C₁₇⋅h
#                                                              -4⋅C₁₉
#                                  C10*h^3/2 - C7 + C8*h - 3*C9*h^2/4
#                                      -2*C12 + 2*C13*h - 3*C14*h^2/2
#                                                    -3⋅C₁₆ + 3⋅C₁₇⋅h
#                                                              -4⋅C₁₉

# %%
sol = solve(eqs, coeffs)
# Out:
# Dict{Sym{PyCall.PyObject}, Sym{PyCall.PyObject}} with 18 entries:
#   C9  => 2*b*p/h^3
#   C13 => 0
#   C10 => 0
#   C11 => p/4
#   C14 => -p/h^3
#   C20 => 0
#   C7  => -3*b*p/(2*h)
#   C2  => 0
#   C18 => 0
#   C15 => 0
#   C4  => 0
#   C19 => 0
#   C16 => 0
#   C3  => (-10*b^2*p - h^2*p)/(10*h^3)
#   C8  => 0
#   C17 => 0
#   C5  => p/(5*h^3)
#   C12 => 3*p/(4*h)

# %%
ϕ_sol = subs(ϕ, sol)
# Out:
#                                         3      2        2        2  3      5   ↪
#                    3⋅b⋅p⋅x⋅y   2⋅b⋅p⋅x⋅y    p⋅x    3⋅p⋅x ⋅y   p⋅x ⋅y    p⋅y    ↪
# C₀ + C₁⋅y + C₆⋅x - ───────── + ────────── + ──── + ──────── - ─────── + ──── + ↪
#                       2⋅h           3        4       4⋅h         3         3   ↪
#                                    h                            h       5⋅h    ↪
#
# ↪   3 ⎛      2      2  ⎞
# ↪  y ⋅⎝- 10⋅b ⋅p - h ⋅p⎠
# ↪  ─────────────────────
# ↪              3
# ↪          10⋅h

# %%
σx = sx(ϕ_sol)
factor(σx)
# Out:
#      ⎛    2               2       2       2⎞
# -p⋅y⋅⎝30⋅b  - 60⋅b⋅x + 3⋅h  + 30⋅x  - 20⋅y ⎠
# ─────────────────────────────────────────────
#                        3
#                     5⋅h

# %%
σy = sy(ϕ_sol)
# Out:
#                  3
# p   3⋅p⋅y   2⋅p⋅y
# ─ + ───── - ──────
# 2    2⋅h       3
#               h

# %%
τxy = sxy(ϕ_sol)
simplify(τxy)
# Out:
#     ⎛ 2              2         ⎞
# 3⋅p⋅⎝h ⋅(b - x) + 4⋅y ⋅(-b + x)⎠
# ────────────────────────────────
#                  3
#               2⋅h
