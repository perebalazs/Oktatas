# %%
using LowLevelFEM

# %%
gmsh.initialize()

# %%
mat = Material("surf")
prob = Problem([mat], type=:ScalarField)
# Out:
# Problem("", :ScalarField, 3, 1, Material[Material("surf", :Hooke, 200000.0, 0.3, 115384.61538461536, 76923.07692307692, 166666.66666666663, 7.85e-9, 45.0, 4.2e8, 1.2e-5, 1.0e-7, 0.1, 1.0)], 1.0, 0, LowLevelFEM.Geometry("", "", 0, 0, nothing, nothing, nothing, nothing))

# %%
structured_rect_mesh(x0=-1, y0=-1, lx=2, ly=2, n=1, order=2)

# %%
u = ScalarField(prob, "surface", (x, y, z) -> x == 1 && y == -1 ? 1 : 0)
u0 = showElementResults(u, visible=true)
gmsh.view.option.setNumber(u0, "NormalRaise", 1)
gmsh.view.option.setNumber(u0, "AdaptVisualizationGrid", 1)
gmsh.view.option.setNumber(u0, "MaxRecursionLevel", 4)
openPostProcessor()

# %%
gmsh.finalize()
