# %%
using LowLevelFEM

# %%
gmsh.initialize()
gmsh.open("truss1D.geo")
# Out:
# Info    : Reading 'truss1D.geo'...
# Info    : Meshing 1D...
# Info    : Meshing curve 1 (Line)
# Info    : Done meshing 1D (Wall 9.3368e-05s, CPU 9.1e-05s)
# Info    : 3 nodes 4 elements
# Info    : Done reading 'truss1D.geo'

# %%
openPreProcessor()
# Out:
# -------------------------------------------------------
# Version       : 4.15.0-git
# License       : GNU General Public License
# Build OS      : Linux64-sdk
# Build date    : 19700101
# Build host    : amdci7.julia.csail.mit.edu
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blossom Cairo DIntegration Dlopen DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack LinuxJoystick MathEx[contrib] Mesh Metis[contrib] Mmg Mpeg Netgen Nii2mesh ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR TinyXML2[contrib] Untangle Voro++[contrib] WinslowUntangler Zlib tinyobjloader
# FLTK version  : 1.3.8
# OCC version   : 7.9.2
# Packaged by   : root
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------
# Info    : Reading 'truss1D.geo'...
# Info    : Meshing 1D...
# Info    : Meshing curve 1 (Line)
# Info    : Done meshing 1D (Wall 0.000231772s, CPU 0.000222s)
# Info    : 6 nodes 7 elements
# Info    : Done reading 'truss1D.geo'
# Info    : Done

# %%
mat = Material("truss", E=2e5)
prob = Problem([mat], type=:Truss, bandwidth=:Hilbert)
# Out:
# Info    : Hilbert renumbering...
# Info    : Done Hilbert renumbering
# Problem("truss1D", :Truss, 3, 3, Material[Material("truss", :Hooke, 200000.0, 0.3, 115384.61538461536, 76923.07692307692, 166666.66666666663, 7.85e-9, 45.0, 4.2e8, 1.2e-5, 1.0e-7, 0.1, 1.0)], 1.0, 6, LowLevelFEM.Geometry("", "", 0, 0, nothing, nothing, nothing, nothing))

# %%
supp = displacementConstraint("left", ux=0)
suppYZ = displacementConstraint("truss", uy=0, uz=0)
F = load("right", fx=10)
fx = load("truss", fx=1)
# Out:
# BoundaryCondition("truss", nothing, nothing, nothing, nothing, nothing, nothing, 1, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing, nothing)

# %%
K = stiffnessMatrix(prob)
K[:, :]
# Out:
# 18×18 SparseArrays.SparseMatrixCSC{Float64, Int64} with 16 stored entries:
# ⎡⡁⢈⠀⡀⠀⠀⠀⠀⠀⎤
# ⎢⠀⠠⠀⠄⠠⠀⠀⠀⠀⎥
# ⎢⠀⠀⠀⠂⠐⠀⠀⠐⠀⎥
# ⎢⠀⠀⠀⠀⢀⠀⡁⢈⠀⎥
# ⎣⠀⠀⠀⠀⠀⠀⠀⠀⠀⎦

# %%
free = freeDoFs(prob, [suppYZ])
K[free, free]
# Out:
# 6×6 SparseArrays.SparseMatrixCSC{Float64, Int64} with 16 stored entries:
#   20000.0  -10000.0        ⋅         ⋅   -10000.0        ⋅
#  -10000.0   20000.0  -10000.0        ⋅         ⋅         ⋅
#        ⋅   -10000.0   20000.0  -10000.0        ⋅         ⋅
#        ⋅         ⋅   -10000.0   20000.0        ⋅   -10000.0
#  -10000.0        ⋅         ⋅         ⋅    10000.0        ⋅
#        ⋅         ⋅         ⋅   -10000.0        ⋅    10000.0

# %%
cond = freeDoFs(prob, [suppYZ, supp])
K[cond, cond]
# Out:
# 5×5 SparseArrays.SparseMatrixCSC{Float64, Int64} with 13 stored entries:
#   20000.0  -10000.0        ⋅         ⋅         ⋅
#  -10000.0   20000.0  -10000.0        ⋅         ⋅
#        ⋅   -10000.0   20000.0  -10000.0        ⋅
#        ⋅         ⋅   -10000.0   20000.0  -10000.0
#        ⋅         ⋅         ⋅   -10000.0   10000.0

# %%
f = loadVector(prob, [F, fx])
DoFs(f)[:]
# Out:
# 18-element Vector{Float64}:
#  10.0
#   0.0
#   0.0
#  20.0
#   0.0
#   0.0
#  20.000000000000004
#   0.0
#   0.0
#  20.0
#   0.0
#   0.0
#  20.0
#   0.0
#   0.0
#  19.999999999999996
#   0.0
#   0.0

# %%
DoFs(f)[free]
# Out:
# 6-element Vector{Float64}:
#  20.0
#  20.000000000000004
#  20.0
#  19.999999999999996
#  10.0
#  20.0

# %%
DoFs(f)[cond]
# Out:
# 5-element Vector{Float64}:
#  20.0
#  20.000000000000004
#  20.0
#  19.999999999999996
#  20.0

# %%
q = solveDisplacement(K, f, support=[suppYZ, supp])
DoFs(q)[free]
# Out:
# 6-element Vector{Float64}:
#  0.01
#  0.018000000000000002
#  0.02400000000000001
#  0.02800000000000001
#  0.0
#  0.030000000000000013

# %%
q0 = showDoFResults(q, name="elmozdulás")
plotOnPath("truss", q0)
# Out:
# 1

# %%
N = solveAxialForce(q)
N.A
# Out:
# 5-element Vector{Matrix{Float64}}:
#  [100.0; 100.0;;]
#  [80.00000000000003; 80.00000000000003;;]
#  [60.000000000000085; 60.000000000000085;;]
#  [40.00000000000003; 40.00000000000003;;]
#  [20.0; 20.0;;]

# %%
N0 = showElementResults(N, name="rúderő")
plotOnPath("truss", N0)
# Out:
# 3

# %%
fix = constrainedDoFs(prob, [supp])

FT = K * q - f
DoFs(FT)[fix]
# Out:
# 1-element Vector{Float64}:
#  -110.0

# %%
openPostProcessor()
# Out:
# -------------------------------------------------------
# Version       : 4.15.0-git
# License       : GNU General Public License
# Build OS      : Linux64-sdk
# Build date    : 19700101
# Build host    : amdci7.julia.csail.mit.edu
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blossom Cairo DIntegration Dlopen DomHex Eigen[contrib] Fltk GMP Gmm[contrib] Hxt Jpeg Kbipack LinuxJoystick MathEx[contrib] Mesh Metis[contrib] Mmg Mpeg Netgen Nii2mesh ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR TinyXML2[contrib] Untangle Voro++[contrib] WinslowUntangler Zlib tinyobjloader
# FLTK version  : 1.3.8
# OCC version   : 7.9.2
# Packaged by   : root
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------

# %%
gmsh.finalize()
