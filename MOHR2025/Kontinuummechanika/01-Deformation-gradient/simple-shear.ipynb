# %%
using LowLevelFEM
gmsh.initialize()
# Out:
# Error   : Unknown number option 'Mesh.MinQuality'
# Error   : Gmsh has not been initialized
# UndefVarError: `error` not defined in local scope
#
# Suggestion: check for an assignment to a local variable that shadows a global of the same name.
#
# Hint: a global variable of this name also exists in Base.
#
#
#
# Stacktrace:
#
#  [1] getLastError()
#
#    @ LowLevelFEM.gmsh.logger ~/.julia/artifacts/4653460f3c6b714482628cbde55e1ca3845b68b4/lib/gmsh.jl:7093
#
#  [2] initialize(argv::Vector{String}, readConfigFiles::Bool, run::Bool)
#
#    @ LowLevelFEM.gmsh ~/.julia/artifacts/4653460f3c6b714482628cbde55e1ca3845b68b4/lib/gmsh.jl:50
#
#  [3] initialize()
#
#    @ LowLevelFEM.gmsh ~/.julia/artifacts/4653460f3c6b714482628cbde55e1ca3845b68b4/lib/gmsh.jl:46
#
#  [4] top-level scope
#
#    @ ~/Dokumentumok/GitHub/Oktatas/MOHR2025/Kontinuummechanika/01-Deformation-gradient/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W0sZmlsZQ==.jl:2

# %%
gmsh.open("cube.geo")

# %%
mat = material("body")
problem = Problem([mat])

# %%
γ = 0.5
x(X, Y, Z) = X + γ * Y
y(X, Y, Z) = Y
z(X, Y, Z) = Z

# %%
deformation = field("body", fx=x, fy=y, fz=z)
r = vectorField(problem, [deformation])

# %%
showDeformationResults(r, :vector, visible=true)

# %%
openPostProcessor()

# %%
F = r ∘ ∇

# %%
FatP = probe(F, "P")

# %%
R = nodePositionVector(problem)

R = nodesToElements(R)

showDeformationResults(F * R, :vector)

# %%
r = nodesToElements(r)
showDeformationResults(inv(F) * r, :vector)

# %%
openPostProcessor()

# %%
FatP * [1, 0, 0]

# %%
FatP * [0, 1, 0]

# %%
FatP * [1, 1, 0]

# %%
gmsh.finalize()
